# %%
import pandas as pd
import numpy as np

# %%
sales_data = pd.read_csv("VideoGamesSales.csv")

# %%
sales_data
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %%
sales_data.shape
# 5909 rows
# 15 columns
# Out:
# (5909, 15)

# %%
duplicate_rows = sales_data[sales_data.duplicated()]
duplicate_rows
# Out:
#       Rank                                               Name Platform  Year  \
# 9        9                          New Super Mario Bros. Wii      Wii  2010
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 64      60                                     Super Mario 64       DS  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 380    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1658  1649                                         WCW Mayhem       PS  2015
# ...

# %%
duplicate_rows.shape[0]
# Out:
# 16

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5909 non-null   int64
#  1   Name           5909 non-null   object
#  2   Platform       5909 non-null   object
#  3   Year           5909 non-null   int64
#  4   Month          5909 non-null   object
#  5   Genre          5909 non-null   object
#  6   Publisher      5897 non-null   object
#  7   Country        5909 non-null   object
#  8   City           5909 non-null   object
#  9   State          5909 non-null   object
#  10  Region         5882 non-null   object
#  11  NA_Sales       5909 non-null   object
#  12  Global_Sales   5909 non-null   float64
#  13  NA_Profit      5909 non-null   float64
#  14  Global_Profit  5909 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 692.6+ KB

# %%
# Removing duplicates 
sales_data = sales_data.drop_duplicates(keep = 'first')

# %%
sales_data.shape[0]
# Out:
# 5893

# %%
# Check for columns with NULL values
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   object
#  2   Platform       5893 non-null   object
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   object
#  5   Genre          5893 non-null   object
#  6   Publisher      5881 non-null   object
#  7   Country        5893 non-null   object
#  8   City           5893 non-null   object
#  9   State          5893 non-null   object
#  10  Region         5866 non-null   object
#  11  NA_Sales       5893 non-null   object
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 736.6+ KB

# %%
null_check = sales_data['Publisher'].isna().to_frame()

# %%
null_check.to_csv('output.csv', index = False)

# %%
freq_publisher = sales_data['Publisher'].mode()[0]

# %%
sales_data['Publisher'].fillna(freq_publisher, inplace = True)
# Out:
# /tmp/ipykernel_1295/3837751585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['Publisher'].fillna(freq_publisher, inplace = True)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   object
#  2   Platform       5893 non-null   object
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   object
#  5   Genre          5893 non-null   object
#  6   Publisher      5893 non-null   object
#  7   Country        5893 non-null   object
#  8   City           5893 non-null   object
#  9   State          5893 non-null   object
#  10  Region         5866 non-null   object
#  11  NA_Sales       5893 non-null   object
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 736.6+ KB

# %%
sales_data['Region'].mode()[0]
# Out:
# 'West'

# %%
sales_data['Region'].fillna(sales_data['Region'].mode()[0], inplace = True)
# Out:
# /tmp/ipykernel_1295/1013886956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['Region'].fillna(sales_data['Region'].mode()[0], inplace = True)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   object
#  2   Platform       5893 non-null   object
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   object
#  5   Genre          5893 non-null   object
#  6   Publisher      5893 non-null   object
#  7   Country        5893 non-null   object
#  8   City           5893 non-null   object
#  9   State          5893 non-null   object
#  10  Region         5893 non-null   object
#  11  NA_Sales       5893 non-null   object
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 736.6+ KB

# %%
check = sales_data[sales_data['Publisher'].isna()]
check.shape[0]
# Out:
# 0

# %%
check2 = sales_data[sales_data['Region'].isna()]
check2.shape[0]
# Out:
# 0

# %%
sales_data['NA_Sales'] = sales_data['NA_Sales'].replace('[$]','',regex = True)
# Out:
# /tmp/ipykernel_1295/4009865525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data['NA_Sales'] = sales_data['NA_Sales'].replace('[$]','',regex = True)

# %%
sales_data.head(50)
# Out:
#     Rank                                          Name Platform  Year Month  \
# 0      1                                    Wii Sports      Wii  2010   Jan
# 1      2                             Super Mario Bros.      NES  2010   Feb
# 2      3                                Mario Kart Wii      Wii  2010   Mar
# 3      4                             Wii Sports Resort      Wii  2010   Apr
# 4      5                      Pokemon Red/Pokemon Blue       GB  2010   May
# 5      6                                        Tetris       GB  2010   Jun
# 6      7                         New Super Mario Bros.       DS  2010   Jul
# 7      8                                      Wii Play      Wii  2010   Aug
# 8      9                     New Super Mario Bros. Wii      Wii  2010   Sep
# 13    10                                     Duck Hunt      NES  2010   Oct
# 14    11                                    Nintendogs       DS  2010   Nov
# ...

# %%
sales_data = sales_data.astype({'NA_Sales' : float})

# %%
sales_data.dtypes
# Out:
# Rank               int64
# Name              object
# Platform          object
# Year               int64
# Month             object
# Genre             object
# Publisher         object
# Country           object
# City              object
# State             object
# Region            object
# NA_Sales         float64
# Global_Sales     float64
# NA_Profit        float64
# Global_Profit    float64
# dtype: object

# %%
sales_data = sales_data.rename(columns = {'NA_Sales':'National Sales [$]', 'Global_Sales':'Global Sales [$]', 'NA_Profit':'National Profit [$]', 'Global_Profit':'Global Profit [$]'})

# %%
sales_data.head()
# Out:
#    Rank                      Name Platform  Year Month         Genre  \
# 0     1                Wii Sports      Wii  2010   Jan        Sports
# 1     2         Super Mario Bros.      NES  2010   Feb      Platform
# 2     3            Mario Kart Wii      Wii  2010   Mar        Racing
# 3     4         Wii Sports Resort      Wii  2010   Apr        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
#
#   Publisher        Country        City       State   Region  \
# 0  Nintendo  United States   Fairfield  California     West
# 1  Nintendo  United States     Edmonds  Washington     West
# 2  Nintendo  United States  Louisville    Kentucky    South
# 3  Nintendo  United States  Round Rock       Texas  Central
# 4  Nintendo  United States   Nashville   Tennessee    South
#
#    National Sales [$]  Global Sales [$]  National Profit [$]  \
# 0               41.49             82.74               12.447
# 1               29.08             40.24                8.724
# ...

# %%
sales_data.dtypes
# Out:
# Rank                     int64
# Name                    object
# Platform                object
# Year                     int64
# Month                   object
# Genre                   object
# Publisher               object
# Country                 object
# City                    object
# State                   object
# Region                  object
# National Sales [$]     float64
# Global Sales [$]       float64
# National Profit [$]    float64
# Global Profit [$]      float64
# dtype: object

# %%
sales_data['Country'] = sales_data['Country'].replace('USA', 'United States')

# %%
sales_data.head(50)
# Out:
#     Rank                                          Name Platform  Year Month  \
# 0      1                                    Wii Sports      Wii  2010   Jan
# 1      2                             Super Mario Bros.      NES  2010   Feb
# 2      3                                Mario Kart Wii      Wii  2010   Mar
# 3      4                             Wii Sports Resort      Wii  2010   Apr
# 4      5                      Pokemon Red/Pokemon Blue       GB  2010   May
# 5      6                                        Tetris       GB  2010   Jun
# 6      7                         New Super Mario Bros.       DS  2010   Jul
# 7      8                                      Wii Play      Wii  2010   Aug
# 8      9                     New Super Mario Bros. Wii      Wii  2010   Sep
# 13    10                                     Duck Hunt      NES  2010   Oct
# 14    11                                    Nintendogs       DS  2010   Nov
# ...

# %%
# To make let's say the first letter of a name or a country uppercase
sales_data['Country'] = sales_data['Country'].str.title()

# %%
sales_cap = sales_data['National Sales [$]'].quantile(0.99)
sales_cap
# Out:
# 4.99

# %%
sales_cap1 = sales_data['Global Sales [$]'].quantile(0.99)
sales_cap1
# Out:
# 10.425599999999994

# %%
sales_cap2 = sales_data['National Profit [$]'].quantile(0.99)
sales_cap2
# Out:
# 1.497

# %%
sales_cap3 = sales_data['Global Profit [$]'].quantile(0.99)
sales_cap3
# Out:
# 3.1276799999999985

# %%
sales_data['National Sales [$]'] = np.where(sales_data['National Sales [$]'] > sales_cap, sales_cap, sales_data['National Sales [$]'])
sales_data['Global Sales [$]'] = np.where(sales_data['Global Sales [$]'] > sales_cap1, sales_cap1, sales_data['Global Sales [$]'])
sales_data['National Profit [$]'] = np.where(sales_data['National Profit [$]'] > sales_cap2, sales_cap2, sales_data['National Profit [$]'])
sales_data['Global Profit [$]'] = np.where(sales_data['Global Profit [$]'] > sales_cap3, sales_cap3, sales_data['Global Profit [$]'])

# %%
sales_data.head(10)
# Out:
#     Rank                       Name Platform  Year Month         Genre  \
# 0      1                 Wii Sports      Wii  2010   Jan        Sports
# 1      2          Super Mario Bros.      NES  2010   Feb      Platform
# 2      3             Mario Kart Wii      Wii  2010   Mar        Racing
# 3      4          Wii Sports Resort      Wii  2010   Apr        Sports
# 4      5   Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
# 5      6                     Tetris       GB  2010   Jun        Puzzle
# 6      7      New Super Mario Bros.       DS  2010   Jul      Platform
# 7      8                   Wii Play      Wii  2010   Aug          Misc
# 8      9  New Super Mario Bros. Wii      Wii  2010   Sep      Platform
# 13    10                  Duck Hunt      NES  2010   Oct       Shooter
#
#    Publisher        Country        City       State   Region  \
# 0   Nintendo  United States   Fairfield  California     West
# 1   Nintendo  United States     Edmonds  Washington     West
# ...

# %%
sales_data = sales_data.round({'National Sales [$]': 2, 'Global Sales [$]': 2, 'National Profit [$]':2, 'Global Profit [$]':2})

# %%
sales_data.head(3)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo
# 2     3     Mario Kart Wii      Wii  2010   Mar    Racing  Nintendo
#
#          Country        City       State Region  National Sales [$]  \
# 0  United States   Fairfield  California   West                4.99
# 1  United States     Edmonds  Washington   West                4.99
# 2  United States  Louisville    Kentucky  South                4.99
#
#    Global Sales [$]  National Profit [$]  Global Profit [$]
# 0             10.43                  1.5               3.13
# 1             10.43                  1.5               3.13
# 2             10.43                  1.5               3.13

# %%
# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
National_Sales = sales_data.groupby(['Region','Country'])['National Sales [$]'].sum().reset_index().sort_values(by = 'National Sales [$]', ascending = False)
National_Sales
# Out:
#   Region        Country  National Sales [$]
# 7   West  United States              951.49
# 1   East  United States              754.35
# 6   West      Australia              687.18
# 3  North  United States              644.19
# 5  South  United States              471.75
# 2  North      Australia               39.89
# 4  South      Australia               16.30
# 0   East      Australia                1.35

# %%
# Create a bar chart
plt.figure(figsize = (16,8))
sns. barplot(data = National_Sales, x = 'Region', y = 'National Sales [$]', hue = 'Country')
plt.title('National Sales by Region and Country', fontweight = 'bold')
plt.xlabel('Region', fontweight = 'bold')
plt.ylabel('National Sales [$]', fontweight = 'bold')
plt.show()

# %%
#Create a box plot
plt.figure(figsize = (12,6))
sns.boxplot(x = 'Country', y = 'National Sales [$]', data = sales_data, showmeans= True, hue = 'Genre', meanprops = {'marker': 'o', 
                                                                                                                     'markerfacecolor':'white',
                                                                                                                     'markersize': '6',
                                                                                                                     'markeredgecolor':'green'}
            )
plt.title('National Sales by Country', fontweight = 'bold')
plt.xlabel('Country', fontweight = 'bold')
plt.ylabel('National Sales [$]', fontweight = 'bold')
plt.show()

# %%
#Create a pie chart
Sales = sales_data.groupby('Country')[['National Sales [$]','Global Sales [$]']].sum().reset_index()
Sales
# Out:
#          Country  National Sales [$]  Global Sales [$]
# 0      Australia              744.72           1468.25
# 1  United States             2821.78           5822.90

# %%
Country = Sales['Country']
National_Sales2 = Sales['National Sales [$]']
Global_Sales = Sales['Global Sales [$]']

# %%
fig, axs = plt.subplots(1,2,figsize = (10,7))
axs[0].pie(National_Sales2, labels= Country, autopct = '%1.1f%%', startangle = 90)
axs[0].set_title('National Sales by Country')

axs[1].pie(Global_Sales, labels = Country, autopct = '%1.1f%%', startangle = 90)
axs[1].set_title('Global Sales by Country')

plt.show()

# %%
# Create a line chart
plt.figure(figsize = (10,6))

#Line for National Sales
plt.plot(sales_data['Year'], sales_data['National Sales [$]'], marker = 'o', linestyle = '-', color = 'b', label ='National Sales [$]')

#Line for Global Sales
#plt.plot(sales_data['Year'], sales_data['Global Sales [$]'], marker = 's', linestyle = '--', color = 'g', label ='Global Sales [$]')

#Adding titles and labels
plt.title('National and Global Sales Over Years', fontweight = 'bold')
plt.xlabel('Year', fontweight = 'bold')
plt.ylabel('Sales', fontweight = 'bold')
plt.legend()

#Display the line chart
plt.grid(True)
plt.show()
